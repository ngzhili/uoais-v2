# %%
import json
import matplotlib.pyplot as plt

experiment_folder = './output/R50_rgbdconcat_mlc_occatmask_hom_concat_uoais_sim'

def load_json_arr(json_path):
    lines = []
    with open(json_path, 'r') as f:
        for line in f:
            lines.append(json.loads(line))
    return lines

experiment_metrics = load_json_arr(experiment_folder + '/metrics.json')
# print(experiment_metrics)
iterations = []
# for i,x in enumerate(experiment_metrics):
#     if len(iterations) > 0:
#         if x['iteration'] < max(iterations):
#             iterations = []
#             index = i
#     iterations.append(x['iteration'])

# print(index)
# experiment_metrics = experiment_metrics[index:index+300]
# plt.plot(
#     [x['iteration'] for x in experiment_metrics], 
#     [x['total_loss'] for x in experiment_metrics])
# plt.plot(
#     [x['iteration'] for x in experiment_metrics if 'validation_loss' in x], 
#     [x['validation_loss'] for x in experiment_metrics if 'validation_loss' in x])
# plt.legend(['total_loss', 'validation_loss'], loc='upper left')

metrics = list(experiment_metrics[0].keys())[2:]
for m in metrics:
    if m in ["iteration","time"]:
        metrics.remove(m)
print(metrics)
plt.figure(figsize=(8,25))
for i, m in enumerate(metrics):
    rows = len(metrics) //2 +1
    cols = 2
    plt.subplot(rows,cols,i+1)
    plt.plot(
        [x['iteration'] for x in experiment_metrics], 
        [x[m] for x in experiment_metrics])
    # plt.legend([m], loc='upper left')
    plt.title(m)
# plt.subplot(2,1,2)
# plt.plot(
#     [x['iteration'] for x in experiment_metrics], 
#     [x["loss_amodal_mask"] for x in experiment_metrics])
# plt.legend(['loss_amodal_mask'], loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# ['fast_rcnn/cls_accuracy', 'fast_rcnn/false_negative', 'fast_rcnn/fg_cls_accuracy', 'loss_amodal_mask', 'loss_box_reg', 'loss_cls', 'loss_occ_cls', 'loss_rpn_cls', 'loss_rpn_loc', 'loss_visible_mask', 'lr', 'roi_head/num_bg_samples', 'roi_head/num_fg_samples', 'rpn/num_neg_anchors', 'rpn/num_pos_anchors', 'total_loss']

# %%
list(experiment_metrics[0].keys())[2:]
# Out:
# ['fast_rcnn/cls_accuracy',
#  'fast_rcnn/false_negative',
#  'fast_rcnn/fg_cls_accuracy',
#  'iteration',
#  'loss_amodal_mask',
#  'loss_box_reg',
#  'loss_cls',
#  'loss_occ_cls',
#  'loss_rpn_cls',
#  'loss_rpn_loc',
#  'loss_visible_mask',
#  'lr',
#  'roi_head/num_bg_samples',
#  'roi_head/num_fg_samples',
#  'rpn/num_neg_anchors',
#  'rpn/num_pos_anchors',
#  'time',
#  'total_loss']

# %%
iterations = []
for i,x in enumerate(experiment_metrics):
    if len(iterations) > 0:
        if x['iteration'] < max(iterations):
            iterations = []
            index = i
    iterations.append(x['iteration'])
    # iterations_index = i
index
# Out:
# 804

# %%
experiment_metrics[index]
# Out:
# {'data_time': 0.00990960153285414,
#  'eta_seconds': 28549.41609997768,
#  'fast_rcnn/cls_accuracy': 0.9158995876647889,
#  'fast_rcnn/false_negative': 1.0,
#  'fast_rcnn/fg_cls_accuracy': 0.0,
#  'iteration': 19,
#  'loss_amodal_mask': 1.3798964023590088,
#  'loss_box_reg': 1.9313396215438843,
#  'loss_cls': 34.524593353271484,
#  'loss_occ_cls': 28933.4951171875,
#  'loss_rpn_cls': 9.14513635635376,
#  'loss_rpn_loc': 5.949173212051392,
#  'loss_visible_mask': 1.749930202960968,
#  'lr': 5.995250000000001e-06,
#  'roi_head/num_bg_samples': 374.75,
#  'roi_head/num_fg_samples': 12.0,
#  'rpn/num_neg_anchors': 237.75,
#  'rpn/num_pos_anchors': 18.25,
#  'time': 0.3172862424980849,
#  'total_loss': 29186.92539677024}

# %%
iterations = []
min(iterations)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ngzhili/uoais/plot_training_plots.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B172.27.106.68/home/ngzhili/uoais/plot_training_plots.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> iterations = []
# ----> <a href='vscode-notebook-cell://ssh-remote%2B172.27.106.68/home/ngzhili/uoais/plot_training_plots.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> min(iterations)
#
# ValueError: min() arg is an empty sequence

# %%
iterations = []
for x in experiment_metrics:
    if len(iterations) > 0:
        if x['iteration'] < max(iterations):
            iterations = []
    iterations.append(x['iteration'])
iterations
# Out:
# [19,
#  39,
#  59,
#  79,
#  99,
#  119,
#  139,
#  159,
#  179,
#  199,
#  219,
#  239,
#  259,
#  279,
#  299,
#  319,
#  339,
#  359,
#  379,
#  399,
#  419,
#  439,
#  459,
#  479,
#  499,
#  519,
#  539,
#  559,
#  579,
#  599,
#  619,
#  639,
#  659,
#  679,
#  699,
#  719,
#  739,
#  759,
#  779,
#  799,
#  819,
#  839,
#  859,
#  879,
#  899,
#  919,
#  939,
#  959,
#  979,
#  999,
#  1019,
#  1039,
#  1059,
#  1079,
#  1099,
#  1119,
#  1139,
#  1159,
#  1179,
#  1199,
#  1219,
#  1239,
#  1259,
#  1279,
#  1299,
#  1319,
#  1339,
#  1359,
#  1379,
#  1399,
#  1419,
#  1439,
#  1459,
#  1479,
#  1499,
#  1519,
#  1539,
#  1559,
#  1579,
#  1599,
#  1619,
#  1639,
#  1659,
#  1679,
#  1699,
#  1719,
#  1739,
#  1759,
#  1779,
#  1799,
#  1819,
#  1839,
#  1859,
#  1879,
#  1899,
#  1919,
#  1939,
#  1959,
#  1979,
#  1999,
#  2019,
#  2039,
#  2059,
#  2079,
#  2099,
#  2119,
#  2139,
#  2159,
#  2179,
#  2199,
#  2219,
#  2239,
#  2259,
#  2279,
#  2299,
#  2319,
#  2339,
# ...

# %%
{
    "data_time": 0.010431114998937119,
    "eta_seconds": 29156.327240952814,
    "fast_rcnn/cls_accuracy": 0.9228515625,
    "fast_rcnn/false_negative": 0.8984962406015038,
    "fast_rcnn/fg_cls_accuracy": 0.10150375939849623,
    "iteration": 19,
    "loss_amodal_mask": 1.3527429699897766,
    "loss_box_reg": 1.4047893285751343,
    "loss_cls": 27.745057106018066,
    "loss_occ_cls": 13768.5185546875,
    "loss_rpn_cls": 6.038676738739014,
    "loss_rpn_loc": 5.856603622436523,
    "loss_visible_mask": 1.4906305074691772,
    "lr": 1.2927500000000002e-06,
    "roi_head/num_bg_samples": 391.5,
    "roi_head/num_fg_samples": 17.25,
    "rpn/num_neg_anchors": 232.0,
    "rpn/num_pos_anchors": 24.0,
    "time": 0.3240311984991422,
    "total_loss": 13919.02984637022
}

# %%
experiment_metrics[0]["total_loss"]
# Out:
# 13919.02984637022

# %%
import json
import matplotlib.pyplot as plt

experiment_folder = './output/R50_rgbdconcat_mlc_occatmask_hom_concat_syntable'

def load_json_arr(json_path):
    lines = []
    with open(json_path, 'r') as f:
        for line in f:
            lines.append(json.loads(line))
    return lines

experiment_metrics = load_json_arr(experiment_folder + '/metrics.json')
# print(experiment_metrics)
iterations = []
# for i,x in enumerate(experiment_metrics):
#     if len(iterations) > 0:
#         if x['iteration'] < max(iterations):
#             iterations = []
#             index = i
#     iterations.append(x['iteration'])
current_iter = 0
for i,metric in enumerate(experiment_metrics):
    
    if metric['iteration'] < current_iter:
        index = i
    else:
        pass
    current_iter = metric['iteration']

# print(index)
experiment_metrics = experiment_metrics[index:index+300]
# plt.plot(
#     [x['iteration'] for x in experiment_metrics], 
#     [x['total_loss'] for x in experiment_metrics])
# plt.plot(
#     [x['iteration'] for x in experiment_metrics if 'validation_loss' in x], 
#     [x['validation_loss'] for x in experiment_metrics if 'validation_loss' in x])
# plt.legend(['total_loss', 'validation_loss'], loc='upper left')

metrics = list(experiment_metrics[0].keys())[2:]
for m in metrics:
    if m in ["iteration","time"]:
        metrics.remove(m)
print(metrics)
plt.figure(figsize=(8,25))
for i, m in enumerate(metrics):
    rows = len(metrics) //2 +1
    cols = 2
    plt.subplot(rows,cols,i+1)
    plt.plot(
        [x['iteration'] for x in experiment_metrics], 
        [x[m] for x in experiment_metrics])
    # plt.legend([m], loc='upper left')
    plt.title(m)
# plt.subplot(2,1,2)
# plt.plot(
#     [x['iteration'] for x in experiment_metrics], 
#     [x["loss_amodal_mask"] for x in experiment_metrics])
# plt.legend(['loss_amodal_mask'], loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# ['fast_rcnn/cls_accuracy', 'fast_rcnn/false_negative', 'fast_rcnn/fg_cls_accuracy', 'loss_amodal_mask', 'loss_box_reg', 'loss_cls', 'loss_occ_cls', 'loss_rpn_cls', 'loss_rpn_loc', 'loss_visible_mask', 'lr', 'roi_head/num_bg_samples', 'roi_head/num_fg_samples', 'rpn/num_neg_anchors', 'rpn/num_pos_anchors', 'total_loss']

# %%
current_iter = 0
for i,metric in enumerate(experiment_metrics):
    
    if metric['iteration'] < current_iter:
        index = i
    else:
        pass
    current_iter = metric['iteration']

# %%
experiment_metrics[index]
# Out:
# {'data_time': 0.010248625418171287,
#  'eta_seconds': 24851.588466656394,
#  'fast_rcnn/cls_accuracy': 0.8401702786377709,
#  'fast_rcnn/false_negative': 0.8566666666666667,
#  'fast_rcnn/fg_cls_accuracy': 0.1433333333333333,
#  'iteration': 19,
#  'loss_amodal_mask': 1.8496469259262085,
#  'loss_box_reg': 7.900509595870972,
#  'loss_cls': 62.916364669799805,
#  'loss_occ_cls': 42521.6953125,
#  'loss_rpn_cls': 2.6791677474975586,
#  'loss_rpn_loc': 7.877915382385254,
#  'loss_visible_mask': 2.383843183517456,
#  'lr': 5.995250000000001e-06,
#  'roi_head/num_bg_samples': 142.5,
#  'roi_head/num_fg_samples': 13.5,
#  'rpn/num_neg_anchors': 237.5,
#  'rpn/num_pos_anchors': 18.5,
#  'time': 0.27619013632647693,
#  'total_loss': 42663.02154046297}
